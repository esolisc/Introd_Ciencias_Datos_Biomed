# %% [markdown]
# <a href="https://colab.research.google.com/github/esolisc/Introd_Ciencias_Datos_Biomed/blob/main/Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Austral.png](data:image/png;base64,...)

# %% [markdown]
# # Repaso semana anterior - Clase 1

# %% [markdown]
# - Los datos ingresan a los algoritmos como números
#
# - Tipos de datos:
#
#   * Enteros (int) - `1 / 2 / 3` ----------------------------------------------> puedo hacer operaciones matemáticas ! También puedo hacer operaciones de comparación (por ejemplo `1>2`. El resultado será `False`)
#   * String (str) - `'qué' / 'copados' / 'los' / 'docentes,' / 'no?' / '9'` ---> los puedo sumar para formar oraciones
#   * Flotantes (float) - `1.037263 / 2.2387426` -------------------------------> puedo aplicar las mismas operaciones que con los núm enteros
#   * Booleanos (bool) - `True / False` ----------------------------------------> le puedo preguntar si se cumple condición A <font color='red'>**Y**</font> condición B, o sino si se cumple condición A <font color='red'>**O**</font> condición B (y lo mismo negando, por ejemplo "no se cumple A...")
#
# _En python, para indicar <font color='red'>**Y**</font> se utiliza el símbolo <font color='red'>**&**</font>_, y para indicar <font color='red'>**O**</font>, se utiliza el símbolo <font color='red'>**|**</font>

# %% [markdown]
# -  Cómo vienen los datos organizados?
#   * como listas: [1,2,3,4,'casa'] ---> notar que está entre corchetes [ ]
#   * como tuplas: (1,2) ---> notar que está entre paréntesis ( )
#   * diccionarios: tengo pareja key-value (llave-valor)... ---> se indica entre llaves { }, y tiene el formato {llave: valor}
#
#   _Ejemplo para entender mejor: imagínense que tienen una base de datos con los DNIs de los empleados y su nombre\_appelido_
#
#   El diccionario luciría del siguiente modo:
#
#  diccionario_de_empleados=  `{DNI 32653826 : Luciana_López,      DNI 16377927 : Sergio_Rossi,      DNI 2868283 : Silvia_Martínez}`
#
#  Cuando yo quiera saber qué dato se corresponde con un dado key (DNI), simplemente tengo que llamar al diccionario en el key cuyo resultado quiero saber:
#
#  diccionario_de_empleados [DNI 32653826] --> El resultado de esto será 'Luciana López'

# %% [markdown]
# - Cómo puedo testear condiciones?
#     * `if, elif, else`  ----> Acá le voy a pedir a python que haga un testeo sobre una condición.
#
#     Defino una variable llamada resultado como ejemplo y aplico if, elif, else

# %%
resultado= 6

if resultado >= 8:
  print('qué buena nota')
elif (resultado ==7):
  print('aprobaste con lo justo')
else:
  print('no aprobaste')
# Out:
# no aprobaste

# %% [markdown]
# - Iteraciones
# * `for` o `while`: le fijan a python una condición para que haga cierto procedimiento
#
# _Ejemplo_
#
# for elemento in range(0:10): <font color='red'>*acá le está diciendo que para cada elemento en el rango de 0 a 10, imprima a ese elemento*</font>
#
#   print(elemento) ----> va a imprimir todos los números desde el 0 al 9 ----> POR QUÉ DESDE 0-9??? porque python empieza a contar desde 0 (no 1), y no cuenta el último valor!!.

# %% [markdown]
# ---

# %% [markdown]
# **Cosas que vimos superficialmente: `numpy`**
#
#
# Es una librería que me permite hacer cálculos matemáticos, principalmente
#
# Trabaja con arrays
#
# y qué son arrays??? 😖 --> algo así como listas de listas!
#
# y por qué es importante para la ciencia de datos??
# ```
# variable 1     var 2        var 3     var p
# [[0.63416088, 0.0036805 , 0.26314535, 0.07313281],  --> individuo 1
#  [0.27752806, 0.93732513, 0.37966094, 0.00646776],  --> individuo 2
#  [0.06458725, 0.13070216, 0.21550122, 0.4226912 ],  --> individuo 3
#  [0.90739466, 0.16860524, 0.97218111, 0.38835089],  --> individuo 4
#  [0.92737367, 0.53012667, 0.28140122, 0.32734719],  --> individuo 5
#  [0.06648707, 0.60041725, 0.93306889, 0.9656621 ]]  --> individuo n
# ```

# %% [markdown]
# con `numpy`es MUY fácil hacer cuentas, calcular estimadores estadísticos, etc...

# %% [markdown]
# ---

# %% [markdown]
# **librería `pandas`**
#
# Es una librería que se utiliza para manipular tablas (_dataframes_)
#
# - Permite seleccionar registros que cumplan cierta condición en alguna de las columnas
# - Posibilita concatenar tablas (por fila, agregando más registros, o por columna, agregando más variables a los registros que ya tenía)
# - Permite agregar(juntar) resultados por algún valor en común (por ejemplo, id)...
#
# Me fijo la altura promedio por grupo _femenino_ o _masculino_
# - gran cantidad de alternativas!!

# %% [markdown]
# ---
# ---
#
# # Clase 2

# %% [markdown]
# # QUÉ VAMOS A VER?
#
# ![image.png](data:image/png;base64,...)
#
# # Resumen
#
# Los datos se extrajeron de la base de datos de MIMIC-III Clinical Database (base de datos pública con información anonimizada de registros electrónicos de salud de 60000 admisiones a UCI (Unidad de cuidados intensivos)). Los pacientes estuvieron en el centro médico Beth Israel Deaconess Medical Center entre 2001 y 2012. La base de datos MIMIC-III database se describe en:
#
# <font color='lightblue'>_Johnson AEW, Pollard TJ, Shen L, Lehman L, Feng M, Ghassemi M, Moody B, Szolovits P, Celi LA, Mark RG. MIMIC-III, a freely accessible critical care database. Scientific Data (2016)._</font>
#
#
# # 1. Importar módulos y librerías
#
# Se utilizará el ID único de la estadía como el índice del dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import seaborn as sns
plt.style.use('ggplot')

data = pd.read_csv('https://www.dropbox.com/s/698ddlyl5yzgpjp/ICUmortality.csv?raw=1',index_col='icustay')

# %% [markdown]
# # 2. Análisis exploratorio

# %%
data.head()
# Out:
#              hours  diastolic BP  glasgow coma scale  glucose  heart rate  \
# icustay
# 282372.0  0.066667          60.0                 NaN      NaN       139.0
# 282372.0  0.150000          73.0                 NaN      NaN       128.0
# 282372.0  0.233333          81.0                 NaN      NaN       127.0
# 282372.0  0.316667          86.0                 NaN      NaN       132.0
# 282372.0  0.400000          86.0                 NaN      NaN       138.0
#
#              mean BP  oxygen saturation  respiratory rate  systolic BP  \
# icustay
# 282372.0   84.666702              100.0              20.0        134.0
# 282372.0   93.000000              100.0              25.0        133.0
# 282372.0   88.666702              100.0              22.0        104.0
# 282372.0  100.000000              100.0              19.0        128.0
# 282372.0  100.333000              100.0              21.0        129.0
#
#           temperature        age  gender  height  pH  weight  day  mortality
# icustay
# 282372.0          NaN  48.682393     2.0     NaN NaN    59.0    1          1
# 282372.0          NaN  48.682393     2.0     NaN NaN    59.0    1          1
# 282372.0          NaN  48.682393     2.0     NaN NaN    59.0    1          1
# 282372.0          NaN  48.682393     2.0     NaN NaN    59.0    1          1
# 282372.0          NaN  48.682393     2.0     NaN NaN    59.0    1          1

# %% [markdown]
# El dataset contiene información:
#
# * Demográfica (edad, género, peso, altura, mortalidad)
#
# * Signos vitales (presión diastólica, presión sistólica, presión media, temperatura, tasa respiratoria)
#
# * Laboratorio (glucosa, pH)
#
# * Scores (escala glasgow - coma)
#
# Cada medición está asociada con estampa de tiempo (columna 'hours'), que indica el número de horas desde la admisión a UCI, cuando las medidas se empezaron a tomar.

# %% [markdown]
# **Estadística**

# %%
print('Número de estadías UCI: ' + str(len(data.index.unique())))
df = data.groupby(['icustay']).mean()
print('Número de supervivientes: ' + str(df[df['mortality'] == 0].count()['mortality']))
print('Número de no supervivientes: ' + str(df[df['mortality'] == 1].count()['mortality']))
print('Mortalidad: ' + str(round(100*df[df['mortality'] == 1].sum()['mortality'] / len(data.index.unique()),1)) + '%')
# Out:
# Número de estadías UCI: 21139
# Número de supervivientes: 18342
# Número de no supervivientes: 2797
# Mortalidad: 13.2%

# %% [markdown]
# Información estadística

# %%
data.shape
# Out:
# (1461282, 17)

# %%
data.columns
# Out:
# Index(['hours', 'diastolic BP', 'glasgow coma scale', 'glucose', 'heart rate',
#        'mean BP', 'oxygen saturation', 'respiratory rate', 'systolic BP',
#        'temperature', 'age', 'gender', 'height', 'pH', 'weight', 'day',
#        'mortality'],
#       dtype='object')

# %%
print(data.info(verbose=True, show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1461282 entries, 282372.0 to 245756.0
# Data columns (total 17 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   hours               1461282 non-null  float64
#  1   diastolic BP        1015284 non-null  float64
#  2   glasgow coma scale  159484 non-null   float64
#  3   glucose             248463 non-null   float64
#  4   heart rate          1057554 non-null  float64
#  5   mean BP             1008434 non-null  float64
#  6   oxygen saturation   1065422 non-null  float64
#  7   respiratory rate    1066689 non-null  float64
#  8   systolic BP         1015685 non-null  float64
#  9   temperature         321850 non-null   float64
#  10  age                 1461282 non-null  float64
#  11  gender              1461282 non-null  float64
#  12  height              455361 non-null   float64
#  13  pH                  123580 non-null   float64
#  14  weight              1309930 non-null  float64
#  15  day                 1461282 non-null  int64
#  16  mortality           1461282 non-null  int64
# dtypes: float64(15), int64(2)
# memory usage: 232.9 MB
# None

# %%
display.display(data.describe())
# Out:
#               hours  diastolic BP  glasgow coma scale        glucose  \
# count  1.461282e+06  1.015284e+06       159484.000000  248463.000000
# mean   2.182227e+01  6.105085e+01           11.600668     148.023205
# std    1.421245e+01  2.237985e+02            3.920855    2007.169359
# min    0.000000e+00 -1.300000e+01            3.000000       0.000000
# 25%    8.938958e+00  5.100000e+01            9.000000     106.000000
# 50%    2.091528e+01  5.900000e+01           14.000000     129.000000
# 75%    3.404250e+01  6.800000e+01           15.000000     162.000000
# max    4.800000e+01  1.141090e+05           15.000000  999999.000000
#
#          heart rate       mean BP  oxygen saturation  respiratory rate  \
# count  1.057554e+06  1.008434e+06       1.065422e+06      1.066689e+06
# mean   8.698175e+01  7.857446e+01       9.775436e+01      2.142277e+01
# std    1.994244e+01  1.474818e+02       9.505683e+02      2.280724e+03
# min    0.000000e+00 -3.700000e+01       0.000000e+00      0.000000e+00
# 25%    7.400000e+01  6.700000e+01       9.600000e+01      1.500000e+01
# 50%    8.500000e+01  7.600000e+01       9.800000e+01      1.900000e+01
# 75%    9.900000e+01  8.700000e+01       1.000000e+02      2.300000e+01
# max    6.632000e+03  1.171200e+05       9.810230e+05      2.355555e+06
#
#         systolic BP    temperature           age        gender         height  \
# count  1.015685e+06  321850.000000  1.461282e+06  1.461282e+06  455361.000000
# mean   1.197301e+02      37.008318  6.535809e+01  1.554603e+00     169.170224
# std    2.928788e+01       9.672449  1.663225e+01  4.970097e-01      14.552301
# min    0.000000e+00      -3.000000  1.803403e+01  1.000000e+00       0.000000
# 25%    1.030000e+02      36.444444  5.474257e+01  1.000000e+00     163.000000
# 50%    1.170000e+02      37.000000  6.738069e+01  2.000000e+00     170.000000
# 75%    1.340000e+02      37.500000  7.862746e+01  2.000000e+00     178.000000
# max    1.375600e+04    5336.111111  9.000000e+01  2.000000e+00     445.000000
#
#                   pH        weight           day     mortality
# count  123580.000000  1.309930e+06  1.461282e+06  1.461282e+06
# mean        7.278925  8.280987e+01  1.439831e+00  1.505267e-01
# std         2.312467  2.575886e+01  4.963666e-01  3.575871e-01
# min         0.000000  0.000000e+00  1.000000e+00  0.000000e+00
# 25%         7.310000  6.650000e+01  1.000000e+00  0.000000e+00
# 50%         7.370000  7.910000e+01  1.000000e+00  0.000000e+00
# 75%         7.420000  9.440000e+01  2.000000e+00  0.000000e+00
# max       733.000000  9.312244e+02  2.000000e+00  1.000000e+00

# %% [markdown]
# Todas las varibles salvo 'hours', 'mortality' y 'day' tienen información faltante.
#
# El análisis de los máximos permite identificar outliers.

# %% [markdown]
# Datos categóricos

# %%
data["mortality"].value_counts().plot.barh(figsize=(10, 4)) #barh
# Out:
# <Axes: >

# %%
data["gender"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='gender'>

# %% [markdown]
# **## Análisis de varaibles numéricas:** `.hist()`, `.kde()` y `.box()`

# %%
data["age"].plot.hist(bins=25, figsize=(10, 4))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Variables Numérica + Numérica: `.scatter()` `.hexbin()`

# %%
data.columns
# Out:
# Index(['hours', 'diastolic BP', 'glasgow coma scale', 'glucose', 'heart rate',
#        'mean BP', 'oxygen saturation', 'respiratory rate', 'systolic BP',
#        'temperature', 'age', 'gender', 'height', 'pH', 'weight', 'day',
#        'mortality'],
#       dtype='object')

# %%
data.plot.scatter(x='pH', y='mean BP')
# Out:
# <Axes: xlabel='pH', ylabel='mean BP'>

# %%
data.plot.hexbin(x='pH', y='mean BP', gridsize=25)
# Out:
# <Axes: xlabel='pH', ylabel='mean BP'>

# %%
data.columns
# Out:
# Index(['hours', 'diastolic BP', 'glasgow coma scale', 'glucose', 'heart rate',
#        'mean BP', 'oxygen saturation', 'respiratory rate', 'systolic BP',
#        'temperature', 'age', 'gender', 'height', 'pH', 'weight', 'day',
#        'mortality'],
#       dtype='object')

# %%
data.groupby('gender')['height'].hist(bins=30, alpha=0.5, density=True);

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_caa2c_row0_col0, #T_caa2c_row1_col1, #T_caa2c_row2_col2, #T_caa2c_row3_col3, #T_caa2c_row4_col4, #T_caa2c_row5_col5, #T_caa2c_row6_col6, #T_caa2c_row7_col7, #T_caa2c_row8_col8, #T_caa2c_row9_col9, #T_caa2c_row10_col10, #T_caa2c_row11_col11, #T_caa2c_row12_col12, #T_caa2c_row13_col13, #T_caa2c_row14_col14, #T_caa2c_row15_col15, #T_caa2c_row16_col16 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_caa2c_row0_col1, #T_caa2c_row3_col1, #T_caa2c_row6_col1, #T_caa2c_row6_col8, #T_caa2c_row9_col1, #T_caa2c_row9_col8, #T_caa2c_row12_col13, #T_caa2c_row14_col8, #T_caa2c_row15_col1, #T_caa2c_row16_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_caa2c_row0_col2, #T_caa2c_row7_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_caa2c_row0_col3, #T_caa2c_row0_col11, #T_caa2c_row3_col11, #T_caa2c_row4_col3, #T_caa2c_row4_col11, #T_caa2c_row6_col11, #T_caa2c_row7_col11, #T_caa2c_row11_col3, #T_caa2c_row11_col10, #T_caa2c_row12_col3, #T_caa2c_row14_col3, #T_caa2c_row15_col3, #T_caa2c_row15_col11 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_caa2c_row0_col4, #T_caa2c_row0_col6, #T_caa2c_row1_col6, #T_caa2c_row3_col6, #T_caa2c_row4_col6, #T_caa2c_row5_col6, #T_caa2c_row7_col6, #T_caa2c_row8_col6, #T_caa2c_row9_col6, #T_caa2c_row10_col6, #T_caa2c_row11_col6, #T_caa2c_row12_col6, #T_caa2c_row14_col6, #T_caa2c_row15_col6, #T_caa2c_row16_col6 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_caa2c_row0_col5, #T_caa2c_row3_col5, #T_caa2c_row4_col13, #T_caa2c_row6_col5, #T_caa2c_row6_col13, #T_caa2c_row7_col5, #T_caa2c_row9_col0, #T_caa2c_row9_col5, #T_caa2c_row11_col13, #T_caa2c_row12_col5, #T_caa2c_row14_col5, #T_caa2c_row15_col13 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_caa2c_row0_col7, #T_caa2c_row2_col1, #T_caa2c_row2_col5, #T_caa2c_row2_col6, #T_caa2c_row2_col9, #T_caa2c_row2_col12, #T_caa2c_row2_col16, #T_caa2c_row3_col7, #T_caa2c_row3_col13, #T_caa2c_row4_col0, #T_caa2c_row4_col15, #T_caa2c_row5_col7, #T_caa2c_row6_col7, #T_caa2c_row9_col3, #T_caa2c_row10_col4, #T_caa2c_row10_col7, #T_caa2c_row10_col11, #T_caa2c_row10_col14, #T_caa2c_row11_col7, #T_caa2c_row12_col7, #T_caa2c_row14_col7, #T_caa2c_row14_col10, #T_caa2c_row15_col7, #T_caa2c_row16_col2, #T_caa2c_row16_col7, #T_caa2c_row16_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_caa2c_row0_col8, #T_caa2c_row2_col3, #T_caa2c_row10_col12 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_caa2c_row0_col9 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_caa2c_row0_col10, #T_caa2c_row0_col14, #T_caa2c_row2_col0, #T_caa2c_row6_col4, #T_caa2c_row9_col2, #T_caa2c_row13_col4, #T_caa2c_row14_col4, #T_caa2c_row15_col10, #T_caa2c_row15_col14 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_caa2c_row0_col12, #T_caa2c_row8_col12, #T_caa2c_row14_col16 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_caa2c_row0_col13, #T_caa2c_row1_col5, #T_caa2c_row7_col13, #T_caa2c_row11_col5, #T_caa2c_row11_col8, #T_caa2c_row13_col8, #T_caa2c_row15_col5, #T_caa2c_row16_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_caa2c_row0_col15, #T_caa2c_row15_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_caa2c_row0_col16 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_caa2c_row1_col0, #T_caa2c_row1_col13, #T_caa2c_row3_col0, #T_caa2c_row3_col9, #T_caa2c_row4_col8, #T_caa2c_row5_col15, #T_caa2c_row6_col0, #T_caa2c_row7_col0, #T_caa2c_row9_col13, #T_caa2c_row10_col0, #T_caa2c_row10_col5, #T_caa2c_row11_col0, #T_caa2c_row12_col15, #T_caa2c_row13_col15, #T_caa2c_row14_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_caa2c_row1_col2, #T_caa2c_row8_col16, #T_caa2c_row14_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_caa2c_row1_col3, #T_caa2c_row1_col11, #T_caa2c_row5_col3, #T_caa2c_row5_col11, #T_caa2c_row6_col3, #T_caa2c_row7_col3, #T_caa2c_row8_col3, #T_caa2c_row9_col11, #T_caa2c_row10_col3, #T_caa2c_row10_col9, #T_caa2c_row13_col9, #T_caa2c_row13_col11, #T_caa2c_row15_col8, #T_caa2c_row16_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_caa2c_row1_col4, #T_caa2c_row4_col14, #T_caa2c_row5_col4, #T_caa2c_row9_col14 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_caa2c_row1_col7, #T_caa2c_row13_col7, #T_caa2c_row14_col15 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_caa2c_row1_col8, #T_caa2c_row8_col0, #T_caa2c_row16_col11 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_caa2c_row1_col9, #T_caa2c_row2_col4, #T_caa2c_row8_col5, #T_caa2c_row12_col9, #T_caa2c_row16_col9 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_caa2c_row1_col10, #T_caa2c_row5_col10, #T_caa2c_row8_col10 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_caa2c_row1_col12, #T_caa2c_row4_col2, #T_caa2c_row5_col12, #T_caa2c_row7_col12, #T_caa2c_row9_col12, #T_caa2c_row15_col12 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_caa2c_row1_col14, #T_caa2c_row3_col10, #T_caa2c_row3_col14, #T_caa2c_row5_col14, #T_caa2c_row6_col10, #T_caa2c_row6_col14, #T_caa2c_row7_col10, #T_caa2c_row7_col14, #T_caa2c_row8_col14, #T_caa2c_row13_col10, #T_caa2c_row13_col14 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_caa2c_row1_col15, #T_caa2c_row3_col15, #T_caa2c_row4_col10, #T_caa2c_row6_col15, #T_caa2c_row7_col15, #T_caa2c_row9_col7, #T_caa2c_row10_col15, #T_caa2c_row11_col15 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_caa2c_row1_col16, #T_caa2c_row6_col16, #T_caa2c_row9_col16 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_caa2c_row2_col7, #T_caa2c_row3_col4, #T_caa2c_row9_col10, #T_caa2c_row11_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_caa2c_row2_col8, #T_caa2c_row2_col11, #T_caa2c_row4_col1, #T_caa2c_row12_col2, #T_caa2c_row12_col10, #T_caa2c_row13_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_caa2c_row2_col10 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_caa2c_row2_col13, #T_caa2c_row7_col9, #T_caa2c_row15_col9, #T_caa2c_row16_col14 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_caa2c_row2_col14 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_caa2c_row2_col15, #T_caa2c_row8_col4 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_caa2c_row3_col2, #T_caa2c_row8_col2, #T_caa2c_row15_col16, #T_caa2c_row16_col10 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_caa2c_row3_col8, #T_caa2c_row4_col5, #T_caa2c_row5_col1, #T_caa2c_row7_col1, #T_caa2c_row11_col1, #T_caa2c_row12_col1, #T_caa2c_row12_col8, #T_caa2c_row14_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_caa2c_row3_col12, #T_caa2c_row6_col12 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_caa2c_row3_col16, #T_caa2c_row7_col16 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_caa2c_row4_col7, #T_caa2c_row12_col16 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_caa2c_row4_col9, #T_caa2c_row6_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_caa2c_row4_col12, #T_caa2c_row16_col12 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_caa2c_row4_col16 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_caa2c_row5_col0, #T_caa2c_row9_col15, #T_caa2c_row12_col0, #T_caa2c_row16_col13 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_caa2c_row5_col2, #T_caa2c_row11_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_caa2c_row5_col8, #T_caa2c_row5_col9, #T_caa2c_row6_col9, #T_caa2c_row8_col9, #T_caa2c_row11_col9, #T_caa2c_row14_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_caa2c_row5_col13, #T_caa2c_row8_col7, #T_caa2c_row8_col13, #T_caa2c_row10_col1, #T_caa2c_row10_col8, #T_caa2c_row13_col0, #T_caa2c_row13_col5, #T_caa2c_row16_col5, #T_caa2c_row16_col15 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_caa2c_row5_col16, #T_caa2c_row13_col16 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_caa2c_row7_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_caa2c_row7_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_caa2c_row8_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_caa2c_row8_col11 {
#   backgr

# %%
sns.heatmap(data.corr());

# %%
data.columns
# Out:
# Index(['hours', 'diastolic BP', 'glasgow coma scale', 'glucose', 'heart rate',
#        'mean BP', 'oxygen saturation', 'respiratory rate', 'systolic BP',
#        'temperature', 'age', 'gender', 'height', 'pH', 'weight', 'day',
#        'mortality'],
#       dtype='object')

# %%
data_scatter= data.groupby(data.index).agg('mean')

# %%
sns.jointplot(x='age', y='weight', data=data_scatter, kind='scatter');

# %%
sns.violinplot(x="mortality", y='pH', data=data);

# %%
sns.boxplot(x="mortality", y='pH', data=data);

# %%
sns.countplot(x='mortality', hue='gender', data=data);

# %%
sns.distplot(data['age']);
# Out:
# <ipython-input-25-9ca5ef6545c2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age']);

# %% [markdown]
# ## 2.1. Selección de variables
#
# ### 2.1.1. Agrupar datos por ID de UCI y ver cantidad de datos no-nulos
# Esto me indicará cuántos ID-UCI tienen al menos 1 medición por variable

# %%
print(data.groupby(['icustay']).mean().info(null_counts=1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 21139 entries, 200001.0 to 299995.0
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hours               21139 non-null  float64
#  1   diastolic BP        19154 non-null  float64
#  2   glasgow coma scale  10993 non-null  float64
#  3   glucose             18745 non-null  float64
#  4   heart rate          19282 non-null  float64
#  5   mean BP             19123 non-null  float64
#  6   oxygen saturation   19305 non-null  float64
#  7   respiratory rate    19367 non-null  float64
#  8   systolic BP         19154 non-null  float64
#  9   temperature         18440 non-null  float64
#  10  age                 21139 non-null  float64
#  11  gender              21139 non-null  float64
#  12  height              5370 non-null   float64
#  13  pH                  15489 non-null  float64
#  14  weight              18181 non-null  float64
#  15  day                 21139 non-null  float64
#  16  mortality           21139 non-null  float64
# dtypes: float64(17)
# memory usage: 2.9 MB
# None
# <ipython-input-26-62f636e94e23>:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   print(data.groupby(['icustay']).mean().info(null_counts=1))

# %% [markdown]
# ### 2.1.2. Análisis de NAs
#
# No todas las variables son utilizadas en los modelos.
#
# Usualmente se descartan variables/features con un cierto porcentaje de datos faltantes, o variables que resultan redundantes porque contienen información semejante a otra (ejemplo el peso/altura y el índice de masa corporal).

# %%
sindato = data.isna().sum().sort_values(ascending=False).reset_index(name='# sin datos (NAs)')
sindato[sindato['# sin datos (NAs)']!=0]
# Out:
#                  index  # sin datos (NAs)
# 0                   pH            1337702
# 1   glasgow coma scale            1301798
# 2              glucose            1212819
# 3          temperature            1139432
# 4               height            1005921
# 5              mean BP             452848
# 6         diastolic BP             445998
# 7          systolic BP             445597
# 8           heart rate             403728
# 9    oxygen saturation             395860
# 10    respiratory rate             394593
# 11              weight             151352

# %%
variables = ['diastolic BP', 'glasgow coma scale',
             'glucose', 'heart rate', 'mean BP',
             'oxygen saturation', 'respiratory rate', 'systolic BP',
             'temperature', 'pH']
variables_mort = variables.copy()
variables_mort.append('mortality')

# %% [markdown]
# # 3. Preprocesamiento
# ## 3.1. Outliers
# ### 3.1.1. Visualización de datos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,6))
for i,c in enumerate(variables,1):
  plt.subplot(2,5,i)
  g= sns.boxplot(y=c, data=data, palette='Purples')
  plt.xlabel('')
  plt.ylabel('')
  plt.grid(False)
  plt.title(variables[i-1])
plt.show()

# %%
variable = 'diastolic BP'
plt.scatter(data.index, data[variable])
plt.ylabel(variable)
plt.grid(False)
plt.show()

# %% [markdown]
# ### 3.1.2. Elegir un método para tratar outliers
#
# Idealmente uno debe mantener los valores extremos asociados a pacientes con muy mala condición de salud, y descartar los valores imposibles (temperaturas negativas, por ejemplo) o posibles outliers (latidos por minuto > 250).
#
# En este sentido, se pueden aplicar distintos métodos.
# Una alternativa, es remover los valores que superan ciertos umbrales definidos por expertos (para no eliminar valores extremos (pero posibles).

# %%
nulls_before = data.isnull().sum().sum()

data.loc[data['diastolic BP']>300, 'diastolic BP'] = np.nan
data.loc[data['glucose']>2000, 'glucose'] = np.nan
data.loc[data['heart rate']>400, 'heart rate'] = np.nan
data.loc[data['mean BP']>300, 'mean BP'] = np.nan
data.loc[data['mean BP']<0, 'mean BP'] = np.nan
data.loc[data['systolic BP']>10000,  'systolic BP'] = np.nan
data.loc[data['temperature']>50, 'temperature'] = np.nan
data.loc[data['temperature']<20, 'temperature'] = np.nan
data.loc[data['pH']>7.8, 'pH'] = np.nan
data.loc[data['pH']<6.8, 'pH'] = np.nan
data.loc[data['respiratory rate']>300, 'respiratory rate'] = np.nan
data.loc[data['oxygen saturation']>100, 'oxygen saturation'] = np.nan
data.loc[data['oxygen saturation']<0, 'oxygen saturation'] = np.nan

nulls_now = data.isnull().sum().sum()
print('Número de datos outliers descartados: ' + str(nulls_now - nulls_before))
# Out:
# Número de datos outliers descartados: 7783

# %% [markdown]
# ### 3.1.3. Visualización de datos luego de remover outliers

# %%
plt.figure(figsize=(15,6))
for i,c in enumerate(variables,1):
  plt.subplot(2,5,i)
  g= sns.violinplot(x= 'mortality', y=c, data=data, palette='Purples')
  plt.xlabel('')
  plt.ylabel('')
  plt.grid(False)
  plt.title(variables[i-1])
plt.show()

# %% [markdown]
# ## 3.2. Agrupar datos por hora
#
# Es posible condensar datos y agruparlos por hora (con la media, por ejemplo).

# %%
data['hour'] = data['hours'].apply(np.floor)

# las horas llegan a 48, cambiar 48 a 47
data.loc[data['hour'] == 48, 'hour'] = 47

data_median_hour = data.groupby(['icustay','hour'])[variables_mort].median()

# índice= incustay
data_median_hour = data_median_hour.reset_index(level=(1), drop = False)

# Me quedo sólo con algunas variables
data_median_hour= data_median_hour[['hour', 'diastolic BP', 'glasgow coma scale', 'glucose', 'heart rate',
       'mean BP', 'oxygen saturation', 'respiratory rate', 'systolic BP',
       'temperature', 'pH', 'mortality']]

# Analizo lo que sucede con el paciente cuyo ID de UCI es 299995
display.display(data_median_hour.loc[299995.0])
# Out:
#           hour  diastolic BP  glasgow coma scale  glucose  heart rate  \
# icustay
# 299995.0   1.0          51.0                 7.0      NaN       106.0
# 299995.0   2.0          53.0                 7.0      NaN        90.0
# 299995.0   3.0          66.0                 NaN      NaN        97.0
# 299995.0   4.0          60.0                 9.0    124.0        94.0
# 299995.0   5.0          59.0                 NaN      NaN        89.0
# 299995.0   6.0          59.0                 8.0      NaN        89.0
# 299995.0   7.0          65.0                 NaN      NaN        89.0
# 299995.0   8.0          58.0                 9.0    112.0        90.0
# 299995.0   9.0          61.0                 NaN      NaN        90.0
# 299995.0  10.0          63.0                10.0      NaN        90.0
# 299995.0  11.0          63.0                 NaN      NaN        89.0
# 299995.0  12.0          53.0                10.0      NaN        84.0
# 299995.0  13.0          61.0                 NaN      NaN        78.5
# 299995.0  14.0          63.0                15.0      NaN        83.0
# 299995.0  15.0          67.0                 NaN      NaN        88.0
# 299995.0  16.0          67.0                15.0      NaN        97.0
# 299995.0  17.0          67.0                 NaN      NaN        94.0
# 299995.0  18.0          63.0                15.0      NaN        89.0
# 299995.0  19.0           NaN                 NaN      NaN        92.0
# 299995.0  20.0          69.0                15.0      NaN        88.0
# 299995.0  21.0           NaN                 NaN      NaN        84.0
# 299995.0  22.0          73.0                15.0      NaN        99.0
# 299995.0  23.0           NaN                 NaN      NaN       100.0
# 299995.0  24.0           NaN                15.0      NaN        99.0
# 299995.0  25.0           NaN                 NaN      NaN        94.0
# 299995.0  26.0          72.0                15.0      NaN        90.0
# 299995.0  27.0          72.0                 NaN      NaN        94.0
# 299995.0  28.0          59.0                15.0      NaN        95.0
# 299995.0  29.0           NaN                 NaN      NaN        94.0
# 299995.0  30.0          82.0                15.0      NaN        85.0
# 299995.0  31.0           NaN                 NaN      NaN        89.0
# 299995.0  32.0           NaN                 NaN      NaN        96.0
# 299995.0  33.0           NaN                 NaN      NaN        82.0
# 299995.0  34.0          65.0                 NaN      NaN        82.0
# 299995.0  35.0           NaN                15.0      NaN        85.0
# 299995.0  36.0           NaN                 NaN     85.0        88.0
# 299995.0  37.0           NaN                 NaN      NaN        86.0
# 299995.0  38.0          85.0                15.0      NaN        80.0
# 299995.0  39.0           NaN                 NaN      NaN        78.0
# 299995.0  40.0           NaN                 NaN      NaN        69.0
# 299995.0  41.0           NaN                 NaN      NaN        66.0
# 299995.0  42.0           NaN                15.0      NaN         NaN
# 299995.0  43.0          82.0                 NaN      NaN        74.0
# 299995.0  44.0           NaN                 NaN      NaN        72.0
# 299995.0  45.0           NaN                 NaN      NaN        82.0
# 299995.0  46.0          65.0                15.0      NaN        73.0
#
#           mean BP  oxygen saturation  respiratory rate  systolic BP  \
# icustay
# 299995.0     65.0               94.0              35.5        111.0
# 299995.0     71.0               98.0              27.0        127.0
# 299995.0     89.0               99.0              24.0        150.0
# 299995.0     80.0               98.0              25.0        133.0
# 299995.0     76.0               99.0               4.0        121.0
# 299995.0     74.0               99.0              22.0        110.0
# 299995.0     81.0               97.0              21.0        121.0
# 299995.0     74.0               97.0              22.0        112.0
# 299995.0     78.0               97.0              21.0        119.0
# 299995.0     80.0               97.0               3.0        120.0
# 299995.0     80.0               97.0              19.0        120.0
# 299995.0     69.0               99.0              18.0        110.0
# 299995.0     77.5               97.5              19.0        116.5
# 299995.0     83.0               99.5              22.0        129.0
# 299995.0     79.0               97.0              23.0        121.0
# 299995.0     79.0                NaN              22.0        121.0
# 299995.0     81.0                NaN              25.0        122.0
# 299995.0     76.0                NaN              17.0        131.0
# 299995.0      NaN                NaN              26.0          NaN
# 299995.0     80.0                NaN               NaN        117.0
# 299995.0      NaN                NaN               NaN          NaN
# 299995.0     88.0                NaN              27.0        115.0
# 299995.0      NaN                NaN              27.0          NaN
# 299995.0      NaN                NaN              17.0          NaN
# 299995.0      NaN                NaN              18.0          NaN
# 299995.0     83.0               98.0              18.0        115.0
# 299995.0     83.0                NaN              29.0        115.0
# 299995.0     76.0               98.0              17.0        134.0
# 299995.0      NaN                NaN              18.0          NaN
# 299995.0     95.0               98.0              17.0        151.0
# 299995.0      NaN                NaN              25.0          NaN
# 299995.0      NaN                NaN              25.0          NaN
# 299995.0      NaN                NaN              22.0          NaN
# 299995.0     83.0               96.0              25.0        148.0
# 299995.0      NaN                NaN              23.0          NaN
# 299995.0      NaN                NaN              17.0          NaN
# 299995.0      NaN                NaN              20.0          NaN
# 299995.0      NaN               99.0              13.0        147.0
# 299995.0      NaN                NaN              23.0          NaN
# 299995.0      NaN                NaN              20.0          NaN
# 299995.0      NaN                NaN              16.0          NaN
# 299995.0      NaN                NaN               NaN          NaN
# 299995.0     93.0                NaN              19.0        145.0
# 299995.0      NaN                NaN              20.0          NaN
# 299995.0      NaN                NaN              20.0          NaN
# 299995.0     81.0                NaN              20.0        128.0
#
#           temperature    pH  mortality
# icustay
# 299995.0    37.611109   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    37.833332  7.39        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN  7.40        0.0
# 299995.0    37.500000   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    36.888901   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    36.888901   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    37.166698   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    37.000000   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    37.000000   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    36.555599   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0          NaN   NaN        0.0
# 299995.0    36.555599   NaN        0.0

# %% [markdown]
# ## 3.3. Seleccionar número mínimo de mediciones
#
# Se seleccionan los ID ICU que tengan al menos 2 mediciones para todas las variables.

# %%
# Número de mediciones por variable
min_num_meas = 2

# Defino una función que se queda con los IDs de UCI que tengan al menos "x" cantidad de mediciones por variable
# (en este caso, definida como 2)
def extr_min_num_meas(data_median_hour, min_num_meas):
    data_count = data_median_hour.groupby(['icustay'])[variables_mort].count()

    for col in data_count:
        data_count[col] = data_count[col].apply(lambda x: np.nan if x < min_num_meas else x)

    data_count = data_count.dropna(axis=0, how='any')
    print('Número de estadía UCI: ' + str(data_count.shape[0]))
    print('Número de variables: ' + str(data_count.shape[1]))
    unique_stays = data_count.index.unique()

    data_median_hour = data_median_hour.loc[unique_stays]

    return data_median_hour

# %%
data_median_hour = extr_min_num_meas(data_median_hour, min_num_meas)
# Out:
# Número de estadía UCI: 6931
# Número de variables: 11

# %%
data_median_hour.head()
# Out:
#           hour  diastolic BP  glasgow coma scale  glucose  heart rate  \
# icustay
# 200003.0   0.0          49.0                15.0      NaN       119.0
# 200003.0   1.0          47.0                 NaN      NaN       117.5
# 200003.0   2.0          47.0                 NaN      NaN       117.0
# 200003.0   3.0          60.5                 NaN      NaN       112.0
# 200003.0   4.0          61.0                 NaN      NaN       108.0
#
#           mean BP  oxygen saturation  respiratory rate  systolic BP  \
# icustay
# 200003.0     58.0               97.0              35.0         91.0
# 200003.0     55.0               96.0              33.5         86.0
# 200003.0     56.0               95.0              33.0         82.0
# 200003.0     65.5               93.5              32.5         86.5
# 200003.0     67.0               91.5              37.0         89.5
#
#           temperature  pH  mortality
# icustay
# 200003.0          NaN NaN        0.0
# 200003.0    39.000000 NaN        0.0
# 200003.0    38.277802 NaN        0.0
# 200003.0    37.777802 NaN        0.0
# 200003.0    36.833335 NaN        0.0

# %% [markdown]
# <font color='red'>Miren cuántos datos menos !! <font>
#
# # 4. Exploración de datos preprocesados
# ## 4.1. Gráficos multivariados
# Se grafican relaciones de a dos variables, agrupadas por desenlace.

# %%
sns.set(style="ticks")
data_pairplot= data_median_hour[variables_mort].dropna(axis=0, how='any')

# %%
data_pairplot=data_pairplot.groupby(data_pairplot.index).agg('mean')

# %%
data_pairplot['mortality']=data_pairplot['mortality'].astype(int)
g = sns.pairplot(data_pairplot, hue = 'mortality')

# hide the upper triangle
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

plt.show()

# change back to our preferred style
plt.style.use('ggplot')

# %% [markdown]
# Algunas observaciones:
#
# * Pacientes hipoxicos tinene < SBP
# * SBP correlaciona con MAP (integridad de datos)
# * Fiebre correlaciona con taquicardia

# %% [markdown]
# ## 4.2. Ploteo de datos temporales
#
# Tendencias por desenlace.
#
# ### 4.2.1. Organizar el dataset

# %%
def timeseries_data(data_median_hour, variable, filldata = 1):
    data4clustering = data_median_hour.pivot(columns='hour', values=variable)
    if filldata == 1:
        # first forward fill
        data4clustering = data4clustering.fillna(method='ffill', axis=1)
        # next backward fill
        data4clustering = data4clustering.fillna(method='bfill', axis=1)
        data4clustering = data4clustering.dropna(axis=0, how='all')
    return data4clustering

# %% [markdown]
# ### 4.2.2. Gráficos de valores medios por desenlace.

# %%
for variable in variables:
    data4clustering = timeseries_data(data_median_hour, variable, filldata = 0)
    print('Plotting ' + str(data4clustering.count().sum()) + ' observations from ' + str(data4clustering.shape[0]) + ' ICU stays')
    mortality = data.loc[data4clustering.index]['mortality'].groupby(['icustay']).mean()
    data4clustering_mort = pd.concat([data4clustering, mortality], axis = 1)
    class1 = data4clustering_mort[data4clustering_mort['mortality']==1].drop(columns = ['mortality']).mean()
    class0 = data4clustering_mort[data4clustering_mort['mortality']==0].drop(columns = ['mortality']).mean()
    plt.figure()
    plt.plot(class1)
    plt.grid(False)
    plt.plot(class0)
    plt.xlabel('Horas desde admisión a UCI')
    plt.ylabel('Media ' + variable)
    plt.legend(['No supervivientes', 'Supervivientes'])
    plt.show()
# Out:
# Plotting 308913 observations from 6931 ICU stays
# Plotting 107073 observations from 6931 ICU stays
# Plotting 99885 observations from 6931 ICU stays
# Plotting 310930 observations from 6931 ICU stays
# Plotting 306827 observations from 6931 ICU stays
# Plotting 302563 observations from 6931 ICU stays
# Plotting 305363 observations from 6931 ICU stays
# Plotting 308942 observations from 6931 ICU stays
# Plotting 138124 observations from 6931 ICU stays
# Plotting 60375 observations from 6931 ICU stays

# %% [markdown]
# Se pueden ver claras diferencias entre los grupos!
#
#
# # 5. Feature engineering
# ## 5.1. Construcción de features (variables)
#
# Se crean variables para obtener la mayor cantidad de información posible a partir de los datos.
#
# Para el caso de las series temporales, se podrían construir las siguientes features: máximo, mínimo, media, desvío estándar.
#
# OJO! Cuanta mayor cantidad de feature agrego, se agranda el dataset!

# %%
def feat_transf(data):
    data_max = data.groupby(['icustay'])[variables].max()
    data_max.columns = ['max ' + str(col) for col in data_max.columns]

    data_min = data.groupby(['icustay'])[variables].min()
    data_min.columns = ['min ' + str(col) for col in data_min.columns]

    data_sd = data.groupby(['icustay'])[variables].std()
    data_sd.columns = ['sd ' + str(col) for col in data_sd.columns]

    data_mean = data.groupby(['icustay'])[variables].mean()
    data_mean.columns = ['mean ' + str(col) for col in data_mean.columns]

    data_agg = pd.concat([data_min,data_max,data_sd,data_mean],axis=1)

    return data_agg

data_transf = feat_transf(data_median_hour)
print('Extracted features: ')
display.display(list(data_transf.columns))
print('')
print('Number of ICU stays: ' + str(data_transf.shape[0]))
print('Number of features: ' + str(data_transf.shape[1]))
display.display(data_transf.head())
# Out:
# Extracted features:
# ['min diastolic BP',
#  'min glasgow coma scale',
#  'min glucose',
#  'min heart rate',
#  'min mean BP',
#  'min oxygen saturation',
#  'min respiratory rate',
#  'min systolic BP',
#  'min temperature',
#  'min pH',
#  'max diastolic BP',
#  'max glasgow coma scale',
#  'max glucose',
#  'max heart rate',
#  'max mean BP',
#  'max oxygen saturation',
#  'max respiratory rate',
#  'max systolic BP',
#  'max temperature',
#  'max pH',
#  'sd diastolic BP',
#  'sd glasgow coma scale',
#  'sd glucose',
#  'sd heart rate',
#  'sd mean BP',
#  'sd oxygen saturation',
#  'sd respiratory rate',
#  'sd systolic BP',
#  'sd temperature',
#  'sd pH',
#  'mean diastolic BP',
#  'mean glasgow coma scale',
#  'mean glucose',
#  'mean heart rate',
#  'mean mean BP',
#  'mean oxygen saturation',
#  'mean respiratory rate',
#  'mean systolic BP',
#  'mean temperature',
#  'mean pH']
# Number of ICU stays: 6931
# Number of features: 40
#           min diastolic BP  min glasgow coma scale  min glucose  \
# icustay
# 200003.0              47.0                     5.0         90.0
# 200019.0              30.0                     6.0        117.0
# 200045.0              16.0                     3.0         18.0
# 200059.0              52.0                    10.0        121.0
# 200102.0              35.5                     3.0        117.0
#
#           min heart rate  min mean BP  min oxygen saturation  \
# icustay
# 200003.0            66.0    55.000000                   91.5
# 200019.0            42.0    64.333298                   95.0
# 200045.0            64.0    49.333302                   90.0
# 200059.0            64.5    65.000000                   93.0
# 200102.0            64.0    50.000000                   88.5
#
#           min respiratory rate  min systolic BP  min temperature  min pH  ...  \
# icustay                                                                   ...
# 200003.0                   0.0             82.0        36.388901    7.36  ...
# 200019.0                  11.0            129.0        36.166698    7.36  ...
# 200045.0                   2.0            104.0        36.111111    7.19  ...
# 200059.0                  10.5             89.0        33.055599    7.37  ...
# 200102.0                   4.0             84.0        35.300001    7.34  ...
#
#           mean diastolic BP  mean glasgow coma scale  mean glucose  \
# icustay
# 200003.0          61.446809                10.538462    125.750000
# 200019.0          48.829545                 7.769231    139.300000
# 200045.0          47.958333                12.000000    171.714286
# 200059.0          68.712766                10.250000    166.062500
# 200102.0          51.000000                 7.227273    174.521739
#
#           mean heart rate  mean mean BP  mean oxygen saturation  \
# icustay
# 200003.0        86.744681     75.138298               96.819149
# 200019.0        54.922222     88.499998               99.255556
# 200045.0        87.083333     75.645842               97.512195
# 200059.0        93.728261     91.553191               99.788889
# 200102.0        78.156250     69.458333               95.437500
#
#           mean respiratory rate  mean systolic BP  mean temperature   mean pH
# icustay
# 200003.0              23.130435        104.159574         37.491236  7.419444
# 200019.0              20.122222        167.909091         37.310201  7.370000
# 200045.0              21.936170        130.062500         36.663600  7.281429
# 200059.0              14.776596        131.861702         36.375740  7.413333
# 200102.0              18.687500        115.156250         36.085660  7.382222
#
# [5 rows x 40 columns]
